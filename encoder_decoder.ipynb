# %% [markdown]
# <a href="https://colab.research.google.com/github/ReneeDu320/deep_learning/blob/main/encoder_decoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import unicodedata
import re

raw_data = (
    ('What a ridiculous concept!', 'Quel concept ridicule !'),
    ('Your idea is not entirely crazy.', "Votre idée n'est pas complètement folle."),
    ("A man's worth lies in what he is.", "La valeur d'un homme réside dans ce qu'il est."),
    ('What he did is very wrong.', "Ce qu'il a fait est très mal."),
    ("All three of you need to do that.", "Vous avez besoin de faire cela, tous les trois."),
    ("Are you giving me another chance?", "Me donnez-vous une autre chance ?"),
    ("Both Tom and Mary work as models.", "Tom et Mary travaillent tous les deux comme mannequins."),
    ("Can I have a few minutes, please?", "Puis-je avoir quelques minutes, je vous prie ?"),
    ("Could you close the door, please?", "Pourriez-vous fermer la porte, s'il vous plaît ?"),
    ("Did you plant pumpkins this year?", "Cette année, avez-vous planté des citrouilles ?"),
    ("Do you ever study in the library?", "Est-ce que vous étudiez à la bibliothèque des fois ?"),
    ("Don't be deceived by appearances.", "Ne vous laissez pas abuser par les apparences."),
    ("Excuse me. Can you speak English?", "Je vous prie de m'excuser ! Savez-vous parler anglais ?"),
    ("Few people know the true meaning.", "Peu de gens savent ce que cela veut réellement dire."),
    ("Germany produced many scientists.", "L'Allemagne a produit beaucoup de scientifiques."),
    ("Guess whose birthday it is today.", "Devine de qui c'est l'anniversaire, aujourd'hui !"),
    ("He acted like he owned the place.", "Il s'est comporté comme s'il possédait l'endroit."),
    ("Honesty will pay in the long run.", "L'honnêteté paye à la longue."),
    ("How do we know this isn't a trap?", "Comment savez-vous qu'il ne s'agit pas d'un piège ?"),
    ("I can't believe you're giving up.", "Je n'arrive pas à croire que vous abandonniez."),
)

# %%
def unicode_to_ascii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')


def normalize_string(s):
    s = unicode_to_ascii(s)
    s = re.sub(r'([!.?])', r' \1', s)
    s = re.sub(r'[^a-zA-Z.!?]+', r' ', s)
    s = re.sub(r'\s+', r' ', s)
    return s


raw_data_en, raw_data_fr = list(zip(*raw_data))
raw_data_en, raw_data_fr = list(raw_data_en), list(raw_data_fr)
raw_data_en = [normalize_string(data) for data in raw_data_en]
raw_data_fr_in = ['<start> ' + normalize_string(data) for data in raw_data_fr]
raw_data_fr_out = [normalize_string(data) + ' <end>' for data in raw_data_fr]

en_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
en_tokenizer.fit_on_texts(raw_data_en)
data_en = en_tokenizer.texts_to_sequences(raw_data_en)
data_en = tf.keras.preprocessing.sequence.pad_sequences(data_en,
                                                        padding='post')

fr_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
fr_tokenizer.fit_on_texts(raw_data_fr_in)
fr_tokenizer.fit_on_texts(raw_data_fr_out)
data_fr_in = fr_tokenizer.texts_to_sequences(raw_data_fr_in)
data_fr_in = tf.keras.preprocessing.sequence.pad_sequences(data_fr_in,
                                                           padding='post')

data_fr_out = fr_tokenizer.texts_to_sequences(raw_data_fr_out)
data_fr_out = tf.keras.preprocessing.sequence.pad_sequences(data_fr_out,
                                                            padding='post')

BATCH_SIZE = 5
dataset = tf.data.Dataset.from_tensor_slices(
    (data_en, data_fr_in, data_fr_out))
dataset = dataset.shuffle(20).batch(BATCH_SIZE)


class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, lstm_size):
        super(Encoder, self).__init__()
        self.lstm_size = lstm_size
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.lstm = tf.keras.layers.LSTM(
            lstm_size, return_sequences=True, return_state=True)

    def call(self, sequence, states):
        embed = self.embedding(sequence)
        output, state_h, state_c = self.lstm(embed, initial_state=states)

        return output, state_h, state_c

    def init_states(self, batch_size):
        return (tf.zeros([batch_size, self.lstm_size]),
                tf.zeros([batch_size, self.lstm_size]))


class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, lstm_size):
        super(Decoder, self).__init__()
        self.lstm_size = lstm_size
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.lstm = tf.keras.layers.LSTM(
            lstm_size, return_sequences=True, return_state=True)
        self.dense = tf.keras.layers.Dense(vocab_size)

    def call(self, sequence, state):
        embed = self.embedding(sequence)
        lstm_out, state_h, state_c = self.lstm(embed, state)
        logits = self.dense(lstm_out)

        return logits, state_h, state_c

    def init_states(self, batch_size):
        return (tf.zeros([batch_size, self.lstm_size]),
                tf.zeros([batch_size, self.lstm_size]))


en_vocab_size = len(en_tokenizer.word_index) + 1
fr_vocab_size = len(fr_tokenizer.word_index) + 1

EMBEDDING_SIZE = 32
LSTM_SIZE = 64

encoder = Encoder(en_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)
decoder = Decoder(fr_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)

initial_states = encoder.init_states(1)
encoder_outputs = encoder(tf.constant([[1, 2, 3]]), initial_states)
decoder_outputs = decoder(tf.constant([[1, 2, 3]]), encoder_outputs[1:])


def loss_func(targets, logits):
    crossentropy = tf.keras.losses.SparseCategoricalCrossentropy(
        from_logits=True)
    mask = tf.math.logical_not(tf.math.equal(targets, 0))
    mask = tf.cast(mask, dtype=tf.int64)
    loss = crossentropy(targets, logits, sample_weight=mask)

    return loss


optimizer = tf.keras.optimizers.Adam()


def predict(test_source_text=None):
    if test_source_text is None:
        test_source_text = raw_data_en[np.random.choice(len(raw_data_en))]
    print(test_source_text)
    test_source_seq = en_tokenizer.texts_to_sequences([test_source_text])
    print(test_source_seq)

    en_initial_states = encoder.init_states(1)
    en_outputs = encoder(tf.constant(test_source_seq), en_initial_states)

    de_input = tf.constant([[fr_tokenizer.word_index['<start>']]])
    de_state_h, de_state_c = en_outputs[1:]
    out_words = []

    while True:
        de_output, de_state_h, de_state_c = decoder(
            de_input, (de_state_h, de_state_c))
        de_input = tf.argmax(de_output, -1)
        out_words.append(fr_tokenizer.index_word[de_input.numpy()[0][0]])

        if out_words[-1] == '<end>' or len(out_words) >= 20:
            break

    print(' '.join(out_words))


@tf.function
def train_step(source_seq, target_seq_in, target_seq_out, en_initial_states):
    loss = 0
    with tf.GradientTape() as tape:
        en_outputs = encoder(source_seq, en_initial_states)
        en_states = en_outputs[1:]
        de_states = en_states

        de_outputs = decoder(target_seq_in, de_states)
        logits = de_outputs[0]
        loss = loss_func(target_seq_out, logits)

    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return loss

# %%
NUM_EPOCHS = 300

for e in range(NUM_EPOCHS):
    en_initial_states = encoder.init_states(BATCH_SIZE)
    
    predict()

    for batch, (source_seq, target_seq_in, target_seq_out) in enumerate(dataset.take(-1)):
        loss = train_step(source_seq, target_seq_in,
                          target_seq_out, en_initial_states)

    print('Epoch {} Loss {:.4f}'.format(e + 1, loss.numpy()))
# Out:
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# anniversaire anniversaire qui ne hui ridicule trois trois trois longue idee idee devine parler mannequins ridicule a fois donnez donnez
# Epoch 1 Loss 3.2214
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# ! ne ne avez <end>
# Epoch 2 Loss 3.6176
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# il il il il il il il il il il il il il il il il il il il il
# Epoch 3 Loss 3.2762
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# <end>
# Epoch 4 Loss 3.2689
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# il <end>
# Epoch 5 Loss 3.3104
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# <end>
# Epoch 6 Loss 3.2854
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# il <end>
# Epoch 7 Loss 3.4625
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# <end>
# Epoch 8 Loss 3.6202
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# <end>
# Epoch 9 Loss 3.3912
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# <end>
# Epoch 10 Loss 2.9881
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# il <end>
# Epoch 11 Loss 3.0439
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# vous vous vous <end>
# Epoch 12 Loss 2.8214
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# vous vous vous vous <end>
# Epoch 13 Loss 2.8886
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous vous vous vous <end>
# Epoch 14 Loss 2.7409
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# vous vous vous vous vous <end>
# Epoch 15 Loss 2.8841
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# vous vous vous vous <end>
# Epoch 16 Loss 2.3320
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# vous vous vous vous vous <end>
# Epoch 17 Loss 2.9395
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous vous vous vous vous <end>
# Epoch 18 Loss 2.8105
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# vous vous vous <end>
# Epoch 19 Loss 3.1600
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous vous vous vous vous <end>
# Epoch 20 Loss 3.1119
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# vous vous vous vous <end>
# Epoch 21 Loss 2.7910
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# vous vous vous vous <end>
# Epoch 22 Loss 2.4837
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# vous . <end>
# Epoch 23 Loss 3.1106
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous vous vous vous vous <end>
# Epoch 24 Loss 2.7725
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# vous vous vous vous <end>
# Epoch 25 Loss 2.9202
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# vous vous vous <end>
# Epoch 26 Loss 2.8010
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# vous vous vous vous vous vous <end>
# Epoch 27 Loss 2.4955
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# vous vous vous ? <end>
# Epoch 28 Loss 2.9782
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous vous vous vous ? <end>
# Epoch 29 Loss 2.6212
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# vous vous vous ? <end>
# Epoch 30 Loss 2.4527
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous vous vous ? <end>
# Epoch 31 Loss 2.8541
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# vous vous vous vous vous vous vous vous vous ? <end>
# Epoch 32 Loss 2.5864
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# vous vous vous vous ? <end>
# Epoch 33 Loss 2.5059
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# vous vous vous vous vous vous ? <end>
# Epoch 34 Loss 2.6663
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# est est est est est est . <end>
# Epoch 35 Loss 2.4063
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous vous vous vous ? <end>
# Epoch 36 Loss 2.4114
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# vous vous vous ? <end>
# Epoch 37 Loss 2.0620
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous vous vous vous ? <end>
# Epoch 38 Loss 2.0369
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# vous vous vous vous vous vous ? <end>
# Epoch 39 Loss 2.4500
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# vous vous vous ? <end>
# Epoch 40 Loss 2.1015
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# vous vous vous pas ? <end>
# Epoch 41 Loss 2.5411
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# est est est est l . <end>
# Epoch 42 Loss 2.4890
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous vous pas ? <end>
# Epoch 43 Loss 2.2966
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# vous vous vous pas ? <end>
# Epoch 44 Loss 2.0001
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# vous vous vous vous vous vous vous vous ? ? <end>
# Epoch 45 Loss 2.4590
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# pas pas pas pas pas pas pas pas pas pas pas pas pas pas pas pas pas folle folle folle
# Epoch 46 Loss 2.2077
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# est est est est l l . <end>
# Epoch 47 Loss 2.3823
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# est est est pas pas pas folle . <end>
# Epoch 48 Loss 2.1893
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous vous a vous vous ? <end>
# Epoch 49 Loss 1.9579
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# est est est l l . <end>
# Epoch 50 Loss 2.3276
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous a pas ? <end>
# Epoch 51 Loss 2.3426
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# est est pas pas pas pas ? <end>
# Epoch 52 Loss 1.9211
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# vous vous a a vous ? <end>
# Epoch 53 Loss 2.2559
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# est est pas pas pas ? <end>
# Epoch 54 Loss 2.2274
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je vous vous a vous vous ? <end>
# Epoch 55 Loss 1.9160
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# est est est pas pas pas folle . <end>
# Epoch 56 Loss 2.2169
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je vous vous a pas ? <end>
# Epoch 57 Loss 1.8341
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# est est pas pas pas ? <end>
# Epoch 58 Loss 1.8165
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# est est pas pas pas ? <end>
# Epoch 59 Loss 1.7266
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# vous vous pas pas ? <end>
# Epoch 60 Loss 2.0512
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne pas pas pas pas ? <end>
# Epoch 61 Loss 1.5956
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# est est pas pas pas ? <end>
# Epoch 62 Loss 1.8053
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# est est pas pas pas ? <end>
# Epoch 63 Loss 1.5262
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous vous s il vous ? <end>
# Epoch 64 Loss 1.9290
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ce vous un ? <end>
# Epoch 65 Loss 1.8694
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# l vous a a . <end>
# Epoch 66 Loss 1.4563
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# est est pas pas pas ? <end>
# Epoch 67 Loss 1.5897
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# ce vous a a la . <end>
# Epoch 68 Loss 1.4046
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# ce vous vous s s il il il . <end>
# Epoch 69 Loss 1.5851
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# savez vous un ? <end>
# Epoch 70 Loss 1.4542
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# est est pas pas completement folle . <end>
# Epoch 71 Loss 1.3946
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# vous a de cela cela . <end>
# Epoch 72 Loss 1.5548
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# ce vous vous s s s il il . <end>
# Epoch 73 Loss 1.4138
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous il il s il il les . <end>
# Epoch 74 Loss 1.4768
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom travaillent travaillent tous les deux . <end>
# Epoch 75 Loss 1.4811
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# ce vous a la des ? <end>
# Epoch 76 Loss 1.4305
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee est pas pas completement ? <end>
# Epoch 77 Loss 1.3274
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je je vous a vous vous des ? <end>
# Epoch 78 Loss 1.4820
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez vous vous des citrouilles ? <end>
# Epoch 79 Loss 1.3318
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous vous de de cela tous . <end>
# Epoch 80 Loss 1.2849
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# est est est l completement . <end>
# Epoch 81 Loss 1.4613
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment vous vous il il s il pas pas d un ? <end>
# Epoch 82 Loss 1.3561
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee est pas completement folle . <end>
# Epoch 83 Loss 1.1572
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment vous vous qu il s s il pas d un ? <end>
# Epoch 84 Loss 1.1940
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# il il a est est tres . <end>
# Epoch 85 Loss 1.1609
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il il s s il est l l . <end>
# Epoch 86 Loss 1.1613
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine est est est anniversaire anniversaire aujourd hui <end>
# Epoch 87 Loss 1.0517
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me vous une chance ? <end>
# Epoch 88 Loss 1.1120
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce vous pas un ? <end>
# Epoch 89 Loss 1.0853
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l a a la . <end>
# Epoch 90 Loss 1.1180
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment vous vous qu il s s agit pas d un ? <end>
# Epoch 91 Loss 0.9845
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l a a la . <end>
# Epoch 92 Loss 1.0007
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce vous pas un ? <end>
# Epoch 93 Loss 0.8619
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous vous de de cela les les . <end>
# Epoch 94 Loss 1.0197
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je je arrive a vous des des ? <end>
# Epoch 95 Loss 1.0290
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous avez vous des ? <end>
# Epoch 96 Loss 0.9205
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous vous de de cela cela les . <end>
# Epoch 97 Loss 0.8706
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux mannequins . <end>
# Epoch 98 Loss 0.9565
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# ce vous a la des ? <end>
# Epoch 99 Loss 0.9094
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# ce vous vous s s s il plait ? <end>
# Epoch 100 Loss 0.8454
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est est anniversaire anniversaire hui ! <end>
# Epoch 101 Loss 0.6714
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom mary travaillent tous les deux mannequins . <end>
# Epoch 102 Loss 1.0205
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez abuser les apparences . <end>
# Epoch 103 Loss 0.7574
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je je avoir minutes vous vous ? <end>
# Epoch 104 Loss 0.7866
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est est anniversaire anniversaire hui ! <end>
# Epoch 105 Loss 0.8295
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez abuser les apparences . <end>
# Epoch 106 Loss 0.7328
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# il il est tres tres mal . <end>
# Epoch 107 Loss 0.7941
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete a la longue . <end>
# Epoch 108 Loss 0.7040
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee est pas completement folle . <end>
# Epoch 109 Loss 0.5755
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a est completement . <end>
# Epoch 110 Loss 0.7746
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom mary travaillent tous les deux mannequins . <end>
# Epoch 111 Loss 0.8100
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est l anniversaire hui ! <end>
# Epoch 112 Loss 0.7089
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive a a que vous abandonniez . <end>
# Epoch 113 Loss 0.7018
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# valeur valeur d un homme reside dans ce qu il est . <end>
# Epoch 114 Loss 0.5324
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# il il est tres tres mal . <end>
# Epoch 115 Loss 0.6272
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee est pas completement folle . <end>
# Epoch 116 Loss 0.7210
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous de de excuser ! savez vous anglais ? <end>
# Epoch 117 Loss 0.6344
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est l anniversaire hui ! <end>
# Epoch 118 Loss 0.6905
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l paye a la longue . <end>
# Epoch 119 Loss 0.4673
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez abuser les apparences . <end>
# Epoch 120 Loss 0.6397
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom mary travaillent tous les deux mannequins . <end>
# Epoch 121 Loss 0.7347
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous avez vous des ? <end>
# Epoch 122 Loss 0.6379
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# ce vous a la des ? <end>
# Epoch 123 Loss 0.6317
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive a croire que vous abandonniez . <end>
# Epoch 124 Loss 0.4357
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee est pas completement folle . <end>
# Epoch 125 Loss 0.5423
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il il s agit pas d un piege ? <end>
# Epoch 126 Loss 0.6957
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# ce vous a la des fois ? <end>
# Epoch 127 Loss 0.4590
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est vous etudiez a la bibliotheque des fois ? <end>
# Epoch 128 Loss 0.5658
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 129 Loss 0.4666
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez abuser par les . <end>
# Epoch 130 Loss 0.4250
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire vous abandonniez . <end>
# Epoch 131 Loss 0.3969
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez abuser par les . <end>
# Epoch 132 Loss 0.6154
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il il s s il possedait l endroit . <end>
# Epoch 133 Loss 0.3751
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete a la longue . <end>
# Epoch 134 Loss 0.4206
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# ce vous a la bibliotheque fois ? <end>
# Epoch 135 Loss 0.4138
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom mary travaillent tous les deux comme mannequins . <end>
# Epoch 136 Loss 0.4467
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez abuser par les . <end>
# Epoch 137 Loss 0.5244
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 138 Loss 0.5135
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire vous abandonniez . <end>
# Epoch 139 Loss 0.3648
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire tous les trois . <end>
# Epoch 140 Loss 0.3838
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez abuser par les . <end>
# Epoch 141 Loss 0.3419
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il il s agit pas d un piege ? <end>
# Epoch 142 Loss 0.3683
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 143 Loss 0.3380
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est l anniversaire hui ! <end>
# Epoch 144 Loss 0.3288
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous avez vous des citrouilles ? <end>
# Epoch 145 Loss 0.3834
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il plait ? <end>
# Epoch 146 Loss 0.4307
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# ce vous a la bibliotheque fois ? <end>
# Epoch 147 Loss 0.3347
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez abuser par les . <end>
# Epoch 148 Loss 0.2865
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser apparences . <end>
# Epoch 149 Loss 0.2741
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous avez vous des citrouilles ? <end>
# Epoch 150 Loss 0.3648
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 151 Loss 0.4333
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 152 Loss 0.4797
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est vous etudiez s s il il possedait plait endroit . <end>
# Epoch 153 Loss 0.2950
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir minutes je vous prie ? <end>
# Epoch 154 Loss 0.2502
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire tous les trois . <end>
# Epoch 155 Loss 0.3289
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous avez vous des citrouilles ? <end>
# Epoch 156 Loss 0.2549
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de excuser ! savez vous parler ? <end>
# Epoch 157 Loss 0.3422
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s possedait l endroit . <end>
# Epoch 158 Loss 0.3309
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie m excuser ! savez vous parler ? <end>
# Epoch 159 Loss 0.3454
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir minutes je vous prie ? <end>
# Epoch 160 Loss 0.2827
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup . <end>
# Epoch 161 Loss 0.3075
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me vous une autre ? <end>
# Epoch 162 Loss 0.2528
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 163 Loss 0.3117
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 164 Loss 0.2042
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est vous etudiez s s il vous possedait endroit . <end>
# Epoch 165 Loss 0.3653
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est l anniversaire aujourd hui ! <end>
# Epoch 166 Loss 0.3567
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir minutes je vous prie ? <end>
# Epoch 167 Loss 0.2864
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 168 Loss 0.1805
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir minutes je vous prie ? <end>
# Epoch 169 Loss 0.2551
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 170 Loss 0.2250
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est l anniversaire aujourd hui ! <end>
# Epoch 171 Loss 0.3358
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est l anniversaire aujourd hui ! <end>
# Epoch 172 Loss 0.3212
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup scientifiques . <end>
# Epoch 173 Loss 0.2752
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup scientifiques . <end>
# Epoch 174 Loss 0.2928
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n pas completement folle . <end>
# Epoch 175 Loss 0.2370
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes vous prie ? <end>
# Epoch 176 Loss 0.2587
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par . <end>
# Epoch 177 Loss 0.2394
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete a la longue . <end>
# Epoch 178 Loss 0.2040
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# Epoch 179 Loss 0.2348
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n pas completement folle . <end>
# Epoch 180 Loss 0.2673
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce vous etudiez a la bibliotheque des ? <end>
# Epoch 181 Loss 0.1445
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par . <end>
# Epoch 182 Loss 0.2096
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete a la longue . <end>
# Epoch 183 Loss 0.2331
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 184 Loss 0.2801
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 185 Loss 0.2824
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 186 Loss 0.1992
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 187 Loss 0.1361
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui est l anniversaire aujourd hui ! <end>
# Epoch 188 Loss 0.1706
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup scientifiques . <end>
# Epoch 189 Loss 0.1504
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n pas completement folle . <end>
# Epoch 190 Loss 0.1923
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 191 Loss 0.2116
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes vous prie ? <end>
# Epoch 192 Loss 0.1535
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n pas completement folle . <end>
# Epoch 193 Loss 0.1178
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 194 Loss 0.1657
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous citrouilles ? <end>
# Epoch 195 Loss 0.1503
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# Epoch 196 Loss 0.2046
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup de trois . <end>
# Epoch 197 Loss 0.1789
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup de trois . <end>
# Epoch 198 Loss 0.2051
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il vous ? <end>
# Epoch 199 Loss 0.1553
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il vous ? <end>
# Epoch 200 Loss 0.1385
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me vous une autre chance ? <end>
# Epoch 201 Loss 0.1598
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 202 Loss 0.1525
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s possedait l endroit . <end>
# Epoch 203 Loss 0.1058
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# Epoch 204 Loss 0.1011
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# il a fait est tres mal . <end>
# Epoch 205 Loss 0.1504
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous des ? <end>
# Epoch 206 Loss 0.1816
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 207 Loss 0.1480
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 208 Loss 0.2250
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler ? <end>
# Epoch 209 Loss 0.1204
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 210 Loss 0.1033
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous pas abuser par les apparences . <end>
# Epoch 211 Loss 0.1106
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# Epoch 212 Loss 0.1494
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 213 Loss 0.1268
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il vous ? <end>
# Epoch 214 Loss 0.1406
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 215 Loss 0.1258
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 216 Loss 0.0864
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me vous une autre chance ? <end>
# Epoch 217 Loss 0.1740
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# Epoch 218 Loss 0.1338
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 219 Loss 0.1392
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Epoch 220 Loss 0.1324
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 221 Loss 0.1301
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# Epoch 222 Loss 0.1459
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# Epoch 223 Loss 0.0870
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous des citrouilles ? <end>
# Epoch 224 Loss 0.1140
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 225 Loss 0.1486
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous des citrouilles ? <end>
# Epoch 226 Loss 0.1567
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 227 Loss 0.1241
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce cela veut dire . <end>
# Epoch 228 Loss 0.1002
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# Epoch 229 Loss 0.0936
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# Epoch 230 Loss 0.1301
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# Epoch 231 Loss 0.0861
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous des citrouilles ? <end>
# Epoch 232 Loss 0.1180
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce cela veut dire . <end>
# Epoch 233 Loss 0.1536
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# Epoch 234 Loss 0.1023
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Epoch 235 Loss 0.1256
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# Epoch 236 Loss 0.1000
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 237 Loss 0.1108
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce cela veut dire . <end>
# Epoch 238 Loss 0.1150
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 239 Loss 0.1107
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup de trois . <end>
# Epoch 240 Loss 0.0824
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 241 Loss 0.0991
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# Epoch 242 Loss 0.1242
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 243 Loss 0.1243
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me vous une autre chance ? <end>
# Epoch 244 Loss 0.0718
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# Epoch 245 Loss 0.0973
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 246 Loss 0.0942
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 247 Loss 0.1161
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous des citrouilles ? <end>
# Epoch 248 Loss 0.0921
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous des citrouilles ? <end>
# Epoch 249 Loss 0.1088
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# Epoch 250 Loss 0.0842
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 251 Loss 0.0783
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 252 Loss 0.0822
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 253 Loss 0.0808
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Epoch 254 Loss 0.1028
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 255 Loss 0.1076
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 256 Loss 0.0979
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous des citrouilles ? <end>
# Epoch 257 Loss 0.0534
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il vous plait ? <end>
# Epoch 258 Loss 0.1038
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n pas completement folle . <end>
# Epoch 259 Loss 0.0931
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 260 Loss 0.0588
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# Epoch 261 Loss 0.0925
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 262 Loss 0.0763
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 263 Loss 0.0737
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous pas abuser par les apparences . <end>
# Epoch 264 Loss 0.0832
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n pas completement folle . <end>
# Epoch 265 Loss 0.0460
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Epoch 266 Loss 0.0669
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 267 Loss 0.0997
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Epoch 268 Loss 0.0772
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 269 Loss 0.0645
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Epoch 270 Loss 0.0996
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# Epoch 271 Loss 0.0772
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup de tous . <end>
# Epoch 272 Loss 0.0543
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il vous plait ? <end>
# Epoch 273 Loss 0.0947
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il vous plait ? <end>
# Epoch 274 Loss 0.0661
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce vous etudiez a la bibliotheque des fois ? <end>
# Epoch 275 Loss 0.0784
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Epoch 276 Loss 0.0620
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n pas completement folle . <end>
# Epoch 277 Loss 0.0649
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce cela veut dire . <end>
# Epoch 278 Loss 0.0765
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il est tres mal . <end>
# Epoch 279 Loss 0.0614
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il vous plait ? <end>
# Epoch 280 Loss 0.0744
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# Epoch 281 Loss 0.0453
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup de tous . <end>
# Epoch 282 Loss 0.0495
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Epoch 283 Loss 0.0679
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Epoch 284 Loss 0.0734
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# Epoch 285 Loss 0.0587
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte s il vous plait ? <end>
# Epoch 286 Loss 0.0654
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# Epoch 287 Loss 0.0619
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Epoch 288 Loss 0.0685
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# Epoch 289 Loss 0.0538
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette vous avez vous des citrouilles ? <end>
# Epoch 290 Loss 0.0731
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 291 Loss 0.0525
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# Epoch 292 Loss 0.0473
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# Epoch 293 Loss 0.0539
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la des fois ? <end>
# Epoch 294 Loss 0.0597
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Epoch 295 Loss 0.0602
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# Epoch 296 Loss 0.0399
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me vous une autre chance ? <end>
# Epoch 297 Loss 0.0489
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous des citrouilles ? <end>
# Epoch 298 Loss 0.0643
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Epoch 299 Loss 0.0556
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il est tres mal . <end>
# Epoch 300 Loss 0.0684

# %%
test_sents = (
    'What a ridiculous concept!',
    'Your idea is not entirely crazy.',
    "A man's worth lies in what he is.",
    'What he did is very wrong.',
    "All three of you need to do that.",
    "Are you giving me another chance?",
    "Both Tom and Mary work as models.",
    "Can I have a few minutes, please?",
    "Could you close the door, please?",
    "Did you plant pumpkins this year?",
    "Do you ever study in the library?",
    "Don't be deceived by appearances.",
    "Excuse me. Can you speak English?",
    "Few people know the true meaning.",
    "Germany produced many scientists.",
    "Guess whose birthday it is today.",
    "He acted like he owned the place.",
    "Honesty will pay in the long run.",
    "How do we know this isn't a trap?",
    "I can't believe you're giving up.",
)

for test_sent in test_sents:
    test_sequence = normalize_string(test_sent)
    predict(test_sequence)
# Out:
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il est tres mal . <end>
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me vous une autre chance ? <end>
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary tous les deux comme mannequins . <end>
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous ? <end>
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# pourriez vous fermer la s il vous plait ? <end>
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette annee avez vous des citrouilles ? <end>
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque fois ? <end>
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous pas abuser par les apparences . <end>
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de gens savent ce cela veut reellement dire . <end>
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# est a beaucoup de tous . <end>
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il l endroit . <end>
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
